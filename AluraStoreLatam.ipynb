# %% [markdown]
# <a href="https://colab.research.google.com/github/vanessa-oreza/Alura-Store/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
from matplotlib import pyplot as plt

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %%
tienda2.head()
# Out:
#            Producto  Categoría del Producto    Precio  Costo de envío  \
# 0  Silla de oficina                 Muebles  283600.0         15300.0
# 1         Pandereta  Instrumentos musicales   76800.0          2300.0
# 2         Cama king                 Muebles  443300.0         23800.0
# 3         Cama king                 Muebles  906200.0         46400.0
# 4  Silla de oficina                 Muebles  397800.0         19400.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      04/08/2021  Izabela de León        Medellín             1
# 1      26/11/2020   Blanca Ramirez        Medellín             3
# 2      22/10/2021  Izabela de León         Pereira             5
# 3      04/05/2022    Maria Alfonso            Cali             5
# 4      26/02/2022    Lucas Olivera          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0               Nequi                   1  6.25184 -75.56359
# ...

# %%
tienda3.head()
# Out:
#             Producto  Categoría del Producto     Precio  Costo de envío  \
# 0   Secadora de ropa       Electrodomésticos  1285100.0         66600.0
# 1      Mesa de noche                 Muebles   290100.0         13600.0
# 2  Guitarra acústica  Instrumentos musicales   303500.0         17400.0
# 3  Balón de voleibol    Deportes y diversión    58800.0          3300.0
# 4            Armario                 Muebles   521100.0         25900.0
#
#   Fecha de Compra        Vendedor Lugar de Compra  Calificación  \
# 0      17/12/2021   Camila Rivera     Santa Marta             4
# 1      10/02/2021   Maria Alfonso            Cali             3
# 2      22/01/2023   Lucas Olivera          Bogotá             5
# 3      22/03/2022     Pedro Gomez    Barranquilla             4
# 4      12/01/2022  Blanca Ramirez          Bogotá             1
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   4  11.24079 -74.19904
# ...

# %%
tienda4.head()
# Out:
#               Producto Categoría del Producto     Precio  Costo de envío  \
# 0         Lavavajillas      Electrodomésticos  1084800.0         56000.0
# 1             Cama box                Muebles   473800.0         25400.0
# 2  Balón de baloncesto   Deportes y diversión    23700.0             0.0
# 3  Modelado predictivo                 Libros    57700.0          1300.0
# 4          Auriculares           Electrónicos   138900.0          5600.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      11/11/2022    Rafael Acosta          Bogotá             4
# 1      03/01/2020  Izabela de León          Cúcuta             5
# 2      25/12/2022    Maria Alfonso        Medellín             5
# 3      23/11/2021    Lucas Olivera        Medellín             3
# 4      25/04/2022   Blanca Ramirez          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0  Tarjeta de crédito                   3  4.60971 -74.08175
# ...

# %% [markdown]
# # **Informe ejecutivo**

# %% [markdown]
# ##**Resumen**

# %% [markdown]
# Este proyecto tiene como objetivo asesorar al Sr. Juan en la toma de decisiones sobre cuál de las tiendas de su cadena Alura Store debería vender para emprender un nuevo negocio. Para ello, se realiza un análisis basado en datos de ventas, rendimiento operativo y calificaciones de los clientes en las cuatro tiendas actuales. A partir de esta evaluación comparativa, se identifica la tienda menos eficiente y se presenta una recomendación fundamentada en los resultados.
#
# **Palabras clave**: análisis de datos, tiendas, eficiencia, decisión empresarial, ventas, rendimiento, reseñas de clientes.

# %% [markdown]
# **Abstract**

# %% [markdown]
# This project aims to support Mr. Juan in deciding which store from his Alura Store chain should be sold to launch a new business venture. The analysis is based on sales data, operational performance, and customer reviews from the four existing stores. Through this comparative evaluation, the least efficient store is identified, and a final recommendation is made based on the data.
#
# **Keywords**: data analysis, retail stores, efficiency, business decision, sales, performance, customer reviews.

# %% [markdown]
# ##**Introducción**

# %% [markdown]
# Este documento tiene como propósito identificar cuál de las cuatro tiendas de la cadena "Alura Store", ubicadas en Colombia, presenta un menor desempeño general y, por tanto, podría ser considerada para su venta con miras a iniciar un nuevo emprendimiento.
#
# Para ello, se realiza un análisis exploratorio de datos utilizando Python como herramienta principal. El enfoque se centra en comparar las tiendas a través de distintos indicadores clave de desempeño, tales como:
#
# * Ingresos totales generados por tienda
#
# * Categorías de productos más y menos vendidos
#
# * Productos individuales más y menos vendidos
#
# * Calificaciones promedio de los clientes
#
# * Costos promedio de envío por tienda
#
# Estos indicadores permiten evaluar tanto la rentabilidad como la eficiencia operativa y la percepción de los usuarios. A partir de esta evaluación integral, se busca sustentar una recomendación estratégica basada en datos reales y objetivos, con el fin de apoyar al Sr. Juan en su proceso de toma de decisiones empresariales.

# %% [markdown]
# ## Metodología

# %% [markdown]
# Para identificar cuál de las cuatro tiendas de la cadena Alura Store es la menos eficiente y así recomendar su posible venta, primero se observan los datos. Se cuenta con la siguiente información de cada tienda:
# * Producto
# * Categoría del Producto
# * Precio
# * Costo de envío
# * Fecha de Compra
# * Vendedor
# * Lugar de Compra
# * Calificación
# * Método de pago
# * Cantidad de cuotas
# * Latitud y longitud de las transacciones de pago
#
# Enseguida, se realiza el análisis de facturación que consiste en comparar los ingresos de cada tienda.

# %% [markdown]
# ###1. Análisis de facturación

# %%
Ingreso1 = tienda['Precio'].sum(); Ingreso2 = tienda2['Precio'].sum(); Ingreso3 = tienda3['Precio'].sum(); Ingreso4 = tienda4['Precio'].sum()
print(f'Ingreso 1: {Ingreso1}')
print(f'Ingreso 2: {Ingreso2}')
print(f'Ingreso 3: {Ingreso3}')
print(f'Ingreso 4: {Ingreso4}')
ingreso_minimo=min(Ingreso1,Ingreso2,Ingreso3,Ingreso4)
conversion_dl=0.00023
print(f'El ingreso mínimo es de ${ingreso_minimo} pesos colombianos. El equivalente a dólares es ${round(ingreso_minimo*conversion_dl)}.')
ingreso_maximo=max(Ingreso1,Ingreso2,Ingreso3,Ingreso4)
print(f'El ingreso máximo es de ${ingreso_maximo} pesos colombianos. El equivalente a dólares es ${round(ingreso_maximo*conversion_dl)}.')
print(f'La diferencia que hay entre la tienda con más ventas y la de menos ventas es de ${ingreso_maximo-ingreso_minimo} pesos colombianos. El equivalente a dólares es ${round((ingreso_maximo-ingreso_minimo)*conversion_dl)}.')
plt.bar(['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'], [Ingreso1, Ingreso2, Ingreso3, Ingreso4])

total_ingresos=Ingreso1+Ingreso2+Ingreso3+Ingreso4
print(f'El total de ingresos es de ${total_ingresos} pesos colombianos. El equivalente a dólares es ${round(total_ingresos*conversion_dl)}.')
razon_diferencia_ingresos=((ingreso_maximo-ingreso_minimo)/total_ingresos)*100
razon_diferencia_ingresos

rzn_dif_ing_max=(ingreso_minimo/ingreso_maximo)*100
rzn_dif_ing_max
print(f'¿Cuánto menos vende la tienda con menos ingresos  respecto a la tienda con más ingresos? {100-rzn_dif_ing_max}%.')
# Out:
# Ingreso 1: 1150880400.0
# Ingreso 2: 1116343500.0
# Ingreso 3: 1098019600.0
# Ingreso 4: 1038375700.0
# El ingreso mínimo es de $1038375700.0 pesos colombianos. El equivalente a dólares es $238826.
# El ingreso máximo es de $1150880400.0 pesos colombianos. El equivalente a dólares es $264702.
# La diferencia que hay entre la tienda con más ventas y la de menos ventas es de $112504700.0 pesos colombianos. El equivalente a dólares es $25876.
# El total de ingresos es de $4403619200.0 pesos colombianos. El equivalente a dólares es $1012832.
# ¿Cuánto menos vende la tienda con menos ingresos  respecto a la tienda con más ingresos? 9.775533582811903%.

# %% [markdown]
# A partir de esta tabla se observa que la tienda 4 es la que tiene menos ingresos. Específicamente, un 9.77% menos de ingresos respecto a la tienda con mayores ingresos.

# %% [markdown]
# Como siguiente análisis, se compararán los ventas por categoría de productos.
# Las categorías de las tiendas son:

# %%
categorias=tienda['Categoría del Producto'].unique()
print(sorted(categorias))
# Out:
# ['Artículos para el hogar', 'Deportes y diversión', 'Electrodomésticos', 'Electrónicos', 'Instrumentos musicales', 'Juguetes', 'Libros', 'Muebles']

# %% [markdown]
# ###2. Ventas por categoría

# %%
conteo1=tienda['Categoría del Producto'].value_counts()
x_1=conteo1.iloc[:]
plt.scatter(x_1,categorias)
plt.title('Ventas por categoría Tienda 1')
plt.xlabel('Ventas')
plt.ylabel('Categorías')
plt.show()

# %%
conteo2=tienda2['Categoría del Producto'].value_counts()
x_2=conteo2.iloc[:]
plt.scatter(x_2,categorias)
plt.title('Ventas por categoría  Tienda 2')
plt.xlabel('Ventas')
plt.ylabel('Categorías')
plt.show()

# %%
conteo3=tienda3['Categoría del Producto'].value_counts()
x_3=conteo3.iloc[:]
plt.scatter(x_3,categorias)
plt.title('Ventas por categoría  Tienda 3')
plt.xlabel('Ventas')
plt.ylabel('Categorías')
plt.show()

# %%
conteo4=tienda4['Categoría del Producto'].value_counts()
x_4=conteo4.iloc[:]
plt.scatter(x_4,categorias)
plt.title('Ventas por categoría Tienda 4')
plt.xlabel('Ventas')
plt.ylabel('Categorías')
plt.show()

# %% [markdown]
# Las categorías presentan un patrón similar en todas las tiendas. La categorías con mayor cantidad de ventas son: electrónicos, muebles y juguetes; y las categorías con menor cantidad de ventas son: instrumentos musicales y libros.

# %% [markdown]
# El siguiente análisis será la calificación promedio de cada tienda. Este indicador corresponde a la percepción de los clientes

# %% [markdown]
# ### 3. Calificación promedio de la tienda

# %%
calif_promedio = tienda['Calificación'].sum()/len(tienda)
calif_promedio2 = tienda2['Calificación'].sum()/len(tienda)
calif_promedio3 = tienda3['Calificación'].sum()/len(tienda)
calif_promedio4 = tienda4['Calificación'].sum()/len(tienda)

print(calif_promedio)
print(calif_promedio2)
print(calif_promedio3)
print(calif_promedio4)
# Out:
# 3.976685036032217
# 4.037303942348453
# 4.048325561678677
# 3.99406528189911

# %%
tiendas=['Tienda 1','Tienda 2','Tienda 3','Tienda 4']
calificaciones=[calif_promedio,calif_promedio2,calif_promedio3,calif_promedio4]

plt.plot(tiendas,calificaciones)
plt.title('Calificación promedio por tienda')
plt.xlabel('Tiendas')
plt.ylabel('Calificación promedio')
plt.show()

# %% [markdown]
# Las calificaciones entre las tiendas son muy cercanas. Por una diferencia de centésimas, las Tiendas 2 y 3 superan los 4.00 puntos, mientras que las Tiendas 1 y 4 se encuentran por debajo de este umbral. De estas, la Tienda 1 presenta la calificación más baja del grupo.

# %% [markdown]
# ### 4. Productos más y menos vendidos

# %%
productos1=tienda['Producto'].value_counts()
productos2=tienda2['Producto'].value_counts()
productos3=tienda3['Producto'].value_counts()
productos4=tienda4['Producto'].value_counts()

# %%
mas_vendidos1=productos1[:3]
print(f' Los más vendidos de la Tienda 1 son: {mas_vendidos1}')
menos_vendidos1=productos1[-3:]
print(f' Los menos vendidos de la Tienda 1 son: {menos_vendidos1}')
# Out:
#  Los más vendidos de la Tienda 1 son: Producto
# Microondas       60
# TV LED UHD 4K    60
# Armario          60
# Name: count, dtype: int64
#  Los menos vendidos de la Tienda 1 son: Producto
# Olla de presión              35
# Auriculares con micrófono    33
# Celular ABXY                 33
# Name: count, dtype: int64

# %%
mas_vendidos2=productos2[:3]
print(f' Los más vendidos de la Tienda 2 son: {mas_vendidos2}')
menos_vendidos2=productos2[-3:]
print(f' Los menos vendidos de la Tienda 2 son: {menos_vendidos2}')
# Out:
#  Los más vendidos de la Tienda 2 son: Producto
# Iniciando en programación    65
# Microondas                   62
# Batería                      61
# Name: count, dtype: int64
#  Los menos vendidos de la Tienda 2 son: Producto
# Mesa de comedor    34
# Impresora          34
# Juego de mesa      32
# Name: count, dtype: int64

# %%
mas_vendidos3=productos3[:3]
print(f' Los más vendidos de la Tienda 3 son: {mas_vendidos3}')
menos_vendidos3=productos3[-3:]
print(f' Los menos vendidos de la Tienda 3 son: {menos_vendidos3}')
# Out:
#  Los más vendidos de la Tienda 3 son: Producto
# Kit de bancas      57
# Mesa de comedor    56
# Cama king          56
# Name: count, dtype: int64
#  Los menos vendidos de la Tienda 3 son: Producto
# Mochila                    36
# Microondas                 36
# Bloques de construcción    35
# Name: count, dtype: int64

# %%
mas_vendidos4=productos4[:3]
print(f' Los más vendidos de la Tienda 4 son: {mas_vendidos4}')
menos_vendidos4=productos4[-3:]
print(f' Los menos vendidos de la Tienda 4 son: {menos_vendidos4}')
# Out:
#  Los más vendidos de la Tienda 4 son: Producto
# Cama box                   62
# Cubertería                 59
# Dashboards con Power BI    56
# Name: count, dtype: int64
#  Los menos vendidos de la Tienda 4 son: Producto
# Guitarra acústica     37
# Armario               34
# Guitarra eléctrica    33
# Name: count, dtype: int64

# %%
# prompt: comparar graficamente los productos más vendidos

import matplotlib.pyplot as plt

# Crear un gráfico de barras para comparar los productos más vendidos en cada tienda
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

# Datos para la tienda 1
axes[0, 0].bar(mas_vendidos1.index, mas_vendidos1.values)
axes[0, 0].set_title('Tienda 1: Productos más vendidos')
axes[0, 0].set_xlabel('Producto')
axes[0, 0].set_ylabel('Cantidad Vendida')
axes[0, 0].tick_params(axis='x', rotation=45)

# Datos para la tienda 2
axes[0, 1].bar(mas_vendidos2.index, mas_vendidos2.values)
axes[0, 1].set_title('Tienda 2: Productos más vendidos')
axes[0, 1].set_xlabel('Producto')
axes[0, 1].set_ylabel('Cantidad Vendida')
axes[0, 1].tick_params(axis='x', rotation=45)


# Datos para la tienda 3
axes[1, 0].bar(mas_vendidos3.index, mas_vendidos3.values)
axes[1, 0].set_title('Tienda 3: Productos más vendidos')
axes[1, 0].set_xlabel('Producto')
axes[1, 0].set_ylabel('Cantidad Vendida')
axes[1, 0].tick_params(axis='x', rotation=45)

# Datos para la tienda 4
axes[1, 1].bar(mas_vendidos4.index, mas_vendidos4.values)
axes[1, 1].set_title('Tienda 4: Productos más vendidos')
axes[1, 1].set_xlabel('Producto')
axes[1, 1].set_ylabel('Cantidad Vendida')
axes[1, 1].tick_params(axis='x', rotation=45)


plt.tight_layout()  # Ajusta el espaciado entre subplots
plt.show()

# %% [markdown]
# El análisis de los productos más vendidos permite identificar el perfil del consumidor según la zona, así como el nivel de rotación de inventario, lo cual impacta en la operación logística. En las Tiendas 1 y 3 predominan los muebles del hogar, mientras que en las Tiendas 2 y 4 se combinan con productos de tecnología, lo que podría reflejar un público más joven y diverso.

# %%
# Crear un gráfico de barras para comparar los productos menos vendidos en cada tienda
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

# Datos para la tienda 1
axes[0, 0].bar(menos_vendidos1.index, menos_vendidos1.values)
axes[0, 0].set_title('Tienda 1: Productos menos vendidos')
axes[0, 0].set_xlabel('Producto')
axes[0, 0].set_ylabel('Cantidad Vendida')
axes[0, 0].tick_params(axis='x', rotation=45)

# Datos para la tienda 2
axes[0, 1].bar(menos_vendidos2.index, menos_vendidos2.values)
axes[0, 1].set_title('Tienda 2: Productos menos vendidos')
axes[0, 1].set_xlabel('Producto')
axes[0, 1].set_ylabel('Cantidad Vendida')
axes[0, 1].tick_params(axis='x', rotation=45)


# Datos para la tienda 3
axes[1, 0].bar(menos_vendidos3.index, menos_vendidos3.values)
axes[1, 0].set_title('Tienda 3: Productos menos vendidos')
axes[1, 0].set_xlabel('Producto')
axes[1, 0].set_ylabel('Cantidad Vendida')
axes[1, 0].tick_params(axis='x', rotation=45)

# Datos para la tienda 4
axes[1, 1].bar(menos_vendidos4.index, menos_vendidos4.values)
axes[1, 1].set_title('Tienda 4: Productos menos vendidos')
axes[1, 1].set_xlabel('Producto')
axes[1, 1].set_ylabel('Cantidad Vendida')
axes[1, 1].tick_params(axis='x', rotation=45)


plt.tight_layout()  # Ajusta el espaciado entre subplots
plt.show()

# %% [markdown]
# El análisis de los productos menos vendidos muestra diferencias claras en las preferencias de los clientes según la tienda. Algunos productos, como el microondas o el armario, son muy vendidos en unas tiendas y poco en otras. Esto sugiere que cada sucursal tiene un perfil de cliente distinto. Con estos datos se pueden tomar decisiones estratégicas como ajustar el inventario, personalizar la oferta o mejorar la visibilidad de ciertos producto, para optimizar el espacio y reducir pérdidas.

# %% [markdown]
# ### 5. Envío promedio por tienda

# %%
envio_promedio1 = tienda['Costo de envío'].sum()/len(tienda)
envio_promedio2 = tienda2['Costo de envío'].sum()/len(tienda2)
envio_promedio3 = tienda3['Costo de envío'].sum()/len(tienda3)
envio_promedio4 = tienda4['Costo de envío'].sum()/len(tienda4)
compilacion_envio=[envio_promedio1,envio_promedio2,envio_promedio3,envio_promedio4]
tiendas=['Tienda 1','Tienda 2','Tienda 3','Tienda 4']
envios_promedio=[envio_promedio1,envio_promedio2,envio_promedio3,envio_promedio4]
print(envios_promedio)
# Out:
# [np.float64(26018.60958033065), np.float64(25216.235693090293), np.float64(24805.680373039424), np.float64(23459.457167090754)]

# %%
plt.bar(tiendas,envios_promedio)
plt.title('Costos de envío promedio por tienda')
plt.xlabel('Tiendas')
plt.ylabel('Costos de envío promedio')
plt.show()

# %% [markdown]
# La Tienda 1 presenta el costo de envío más alto, mientras que la Tienda 4 tiene el más bajo, con una diferencia de aproximadamente $2,569.10 COP entre ambas.
#
# Si lo vemos en porcentaje, la Tienda 4 tiene un costo 9.87% menor que el de la Tienda 1.

# %% [markdown]
# **Análisis ingresos menos costo de envío**

# %% [markdown]
# Durante el análisis de las cuatro tiendas de la cadena Alura Store, se observó que la Tienda 4 tenía los ingresos más bajos, pero también el costo promedio de envío más bajo. Como se muestra a continuación:
#
# * Indicador ingresos: la Tienda 4 tiene un 9.77% menos de ingresos respecto a la Tienda 1.
#
# * Indicador costo de envío: la Tienda 4 tiene un costo 9.87% menor que el de la Tienda 1.
#
# Esta relación planteó la pregunta:
# ¿Su eficiencia logística podría compensar su bajo nivel de ingresos?

# %% [markdown]
# Para responder, se realizó un cálculo estimado de ganancia bruta por tienda, utilizando la siguiente fórmula:
#
# Ganancia estimada = Ingresos - (Costo envío promedio * Número total de envíos)

# %%
print(tienda.count())
print(tienda4.count())
# Out:
# Producto                  2359
# Categoría del Producto    2359
# Precio                    2359
# Costo de envío            2359
# Fecha de Compra           2359
# Vendedor                  2359
# Lugar de Compra           2359
# Calificación              2359
# Método de pago            2359
# Cantidad de cuotas        2359
# lat                       2359
# lon                       2359
# dtype: int64
# Producto                  2358
# Categoría del Producto    2358
# Precio                    2358
# Costo de envío            2358
# Fecha de Compra           2358
# Vendedor                  2358
# Lugar de Compra           2358
# Calificación              2358
# Método de pago            2358
# Cantidad de cuotas        2358
# lat                       2358
# lon                       2358
# dtype: int64

# %% [markdown]
# Tienda 1: Ganancia estimada = 1,150,880,400	 - ( 26,018.61 * 2359) = 1,089,514,538.02
#
# Tienda 4: Ganancia estimada = 1,038,375,700	 - ( 23,449.51 * 2358) = 983,102,559.42
#
# Incluso con menores costos logísticos, la Tienda 4 no logra compensar sus ingresos limitados.

# %% [markdown]
# ## Conclusiones

# %% [markdown]
# Luego de analizar los datos de ingresos, calificaciones de los clientes y comportamiento de ventas por producto en las cuatro tiendas de Alura Store, se concluye que la Tienda 4 es la menos eficiente.
#
# Desde el punto de vista financiero, la Tienda 4 presenta el ingreso más bajo, con 1,038,375,700 COP, lo que representa una diferencia de 112,504,700 COP, proximadamente el 9.78% menos respecto a la Tienda 1. A nivel de reseñas, su calificación es inferior a 4.00, ubicándola junto con la Tienda 1 en el grupo de menor valoración por parte de los clientes.
#
# En cuanto al análisis de productos, los artículos menos vendidos en la Tienda 4 (como guitarras y armarios) indican una baja rotación y poco ajuste con la demanda del público, a diferencia de otras tiendas donde productos similares tienen mejor desempeño. Aunque la tienda registra un volumen de unidades vendidas similar a otras, la baja rotación de productos clave y su perfil de ventas menos rentable refuerzan la decisión.
#
# Tanto la Tienda 2 como la Tienda 3 presentan buenas métricas de rendimiento, niveles de ingresos altos, buena percepción del cliente y portafolios alineados con su público. Son tiendas con potencial de crecimiento y no muestran señales claras de ineficiencia.
#
# Por estas razones, se recomienda considerar la venta de la Tienda 4 como una estrategia para liberar recursos, optimizar el rendimiento global de la cadena y facilitar el inicio del nuevo emprendimiento del Sr. Juan.

# %% [markdown]
# ## Líneas futuras de investigación

# %% [markdown]
# A pesar de la conclusión, se insiste en profundizar el análisis con una mayor precisión al considerar el comportamiento a través del tiempo para identificar las tendencias.

# %% [markdown]
# ## Referencias

# %% [markdown]
# Uribe Macías, M. E., Orjuela Ramírez, D. F., & Reyes Parga, M. A. (2022). Análisis de la eficiencia de centros comerciales, a través del análisis envolvente de datos. Revista Facultad De Ciencias Económicas, 30(2), 59–76. https://doi.org/10.18359/rfce.6243
